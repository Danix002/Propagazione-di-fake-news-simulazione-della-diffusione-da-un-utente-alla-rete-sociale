# %% [markdown]
# # Comparazione tra la rete artificiale e la rete reale
#
# Confrontiamo le proprietà strutturali di due grafi: un grafo artificiale generato utilizzando il modello Barabasi-Albert e un grafo reale preso nel sito [SNAP](https://snap.stanford.edu/data/higgs-twitter.html). Le proprietà che esamineremo al fine della comparazione includono:
#
# - Numero di nodi
# - Numero di archi
# - Lunghezza media del cammino più corto
# - Diametro
# - Connettività
# - Distribuzione dei gradi
# - I vari tipi di centrality (Degree, Betwennes, Closeness, Eigenvector)
#
# Il codice seguente calcola, a partire dai grafi, le proprietà desiderate e visualizza i grafici comparativi per metterle a confronto.
#
# # Codice per la Generazione e l'Analisi dei Grafi

# %% [markdown]
# ## Grafico che compara le due reti sulla base del numero dei nodi, degli archi, connettività e diamentro:

# %%
# %run Analysis/nodes_edges_connectivity_diameter_comparation.py

# %% [markdown]
# ## Grafico che compara le due reti sulla base della loro distribuzione del grado:

# %%
# %run Analysis/degree_distribution.py

# %% [markdown]
# ## Grafico che compara le due reti sulla base dei vari tipi di centrality:

# %%
# %run Analysis/centralities_comparation.py
