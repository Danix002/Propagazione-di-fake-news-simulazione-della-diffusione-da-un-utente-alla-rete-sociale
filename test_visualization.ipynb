# %% [markdown]
# # Data visualization - test

# %% [markdown]
# # Choroplet

# %%
# %matplotlib inline
# %run Visualization/choroplet_sample_view.py Infected 1
# Out:
# Regione: Abruzzo, Infected: 10, color: #ffe5e5
# Regione: Basilicata, Infected: 5, color: #fff2f2
# Regione: Calabria, Infected: 22, color: #ffc5c5
# Regione: Campania, Infected: 39, color: #ff9898
# Regione: Emilia-Romagna, Infected: 45, color: #ff8989
# Regione: Friuli-Venezia Giulia, Infected: 10, color: #ffe5e5
# Regione: Lazio, Infected: 33, color: #ffa8a8
# Regione: Liguria, Infected: 14, color: #ffdada
# Regione: Lombardia, Infected: 97, color: #ff0000
# Regione: Marche, Infected: 21, color: #ffc8c8
# Regione: Molise, Infected: 2, color: #fffafa
# Regione: Piemonte, Infected: 33, color: #ffa8a8
# Regione: Puglia, Infected: 52, color: #ff7676
# Regione: Sardegna, Infected: 13, color: #ffdddd
# Regione: Sicilia, Infected: 43, color: #ff8e8e
# Regione: Toscana, Infected: 41, color: #ff9393
# Regione: Trentino-Alto Adige, Infected: 8, color: #ffeaea
# Regione: Umbria, Infected: 11, color: #ffe2e2
# Regione: Valle d'Aosta, Infected: 0, color: #ffffff
# ...

# %%
# %matplotlib inline
# %run Visualization/choroplet_complete_view.py Infected 1
# Out:
# Regione: Abruzzo, Infected: 10, color: #ffe5e5
# Regione: Basilicata, Infected: 5, color: #fff2f2
# Regione: Calabria, Infected: 22, color: #ffc5c5
# Regione: Campania, Infected: 39, color: #ff9898
# Regione: Emilia-Romagna, Infected: 45, color: #ff8989
# Regione: Friuli-Venezia Giulia, Infected: 10, color: #ffe5e5
# Regione: Lazio, Infected: 33, color: #ffa8a8
# Regione: Liguria, Infected: 14, color: #ffdada
# Regione: Lombardia, Infected: 97, color: #ff0000
# Regione: Marche, Infected: 21, color: #ffc8c8
# Regione: Molise, Infected: 2, color: #fffafa
# Regione: Piemonte, Infected: 33, color: #ffa8a8
# Regione: Puglia, Infected: 52, color: #ff7676
# Regione: Sardegna, Infected: 13, color: #ffdddd
# Regione: Sicilia, Infected: 43, color: #ff8e8e
# Regione: Toscana, Infected: 41, color: #ff9393
# Regione: Trentino-Alto Adige, Infected: 8, color: #ffeaea
# Regione: Umbria, Infected: 11, color: #ffe2e2
# Regione: Valle d'Aosta, Infected: 0, color: #ffffff
# ...

# %%
# %matplotlib inline
# %run Visualization/choroplet_sample_view.py Susceptible 2
# Out:
# Regione: Abruzzo, Susceptible: 81, color: #dadaff
# Regione: Basilicata, Susceptible: 36, color: #eeeeff
# Regione: Calabria, Susceptible: 87, color: #d7d7ff
# Regione: Campania, Susceptible: 307, color: #7272ff
# Regione: Emilia-Romagna, Susceptible: 281, color: #7e7eff
# Regione: Friuli-Venezia Giulia, Susceptible: 81, color: #dadaff
# Regione: Lazio, Susceptible: 199, color: #a4a4ff
# Regione: Liguria, Susceptible: 63, color: #e2e2ff
# Regione: Lombardia, Susceptible: 555, color: #0000ff
# Regione: Marche, Susceptible: 95, color: #d3d3ff
# Regione: Molise, Susceptible: 11, color: #fafaff
# Regione: Piemonte, Susceptible: 186, color: #aaaaff
# Regione: Puglia, Susceptible: 316, color: #6e6eff
# Regione: Sardegna, Susceptible: 77, color: #dcdcff
# Regione: Sicilia, Susceptible: 271, color: #8282ff
# Regione: Toscana, Susceptible: 283, color: #7d7dff
# Regione: Trentino-Alto Adige, Susceptible: 28, color: #f2f2ff
# Regione: Umbria, Susceptible: 59, color: #e4e4ff
# ...

# %%
# %matplotlib inline
# %run Visualization/choroplet_complete_view.py Susceptible 2
# Out:
# Regione: Abruzzo, Susceptible: 81, color: #dadaff
# Regione: Basilicata, Susceptible: 36, color: #eeeeff
# Regione: Calabria, Susceptible: 87, color: #d7d7ff
# Regione: Campania, Susceptible: 307, color: #7272ff
# Regione: Emilia-Romagna, Susceptible: 281, color: #7e7eff
# Regione: Friuli-Venezia Giulia, Susceptible: 81, color: #dadaff
# Regione: Lazio, Susceptible: 199, color: #a4a4ff
# Regione: Liguria, Susceptible: 63, color: #e2e2ff
# Regione: Lombardia, Susceptible: 555, color: #0000ff
# Regione: Marche, Susceptible: 95, color: #d3d3ff
# Regione: Molise, Susceptible: 11, color: #fafaff
# Regione: Piemonte, Susceptible: 186, color: #aaaaff
# Regione: Puglia, Susceptible: 316, color: #6e6eff
# Regione: Sardegna, Susceptible: 77, color: #dcdcff
# Regione: Sicilia, Susceptible: 271, color: #8282ff
# Regione: Toscana, Susceptible: 283, color: #7d7dff
# Regione: Trentino-Alto Adige, Susceptible: 28, color: #f2f2ff
# Regione: Umbria, Susceptible: 59, color: #e4e4ff
# ...
