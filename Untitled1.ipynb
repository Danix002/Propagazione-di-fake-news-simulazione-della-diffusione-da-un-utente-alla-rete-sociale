# %%
# %run main_choroplet.py
# Out:
# no display found. Using non-interactive Agg backend
# no display found. Using non-interactive Agg backend
#
#
# <---------TEST:  Debunking test 1: setting as initial recovered seed all the hub of the graph --------->
#
#
# INITIAL STATUS  {0: 1650, 1: 200, 2: 150}
# Iteration:  0 NewSusceptible: -352 NewInfected:  352 NewRecovered:  0 node count:  {0: 1298, 1: 552, 2: 150}
# Iteration:  1 NewSusceptible: -534 NewInfected:  463 NewRecovered:  71 node count:  {0: 764, 1: 1015, 2: 221}
# Iteration:  2 NewSusceptible: -452 NewInfected:  382 NewRecovered:  70 node count:  {0: 312, 1: 1397, 2: 291}
# Iteration:  3 NewSusceptible: -210 NewInfected:  132 NewRecovered:  78 node count:  {0: 102, 1: 1529, 2: 369}
# Iteration:  4 NewSusceptible: -58 NewInfected:  -10 NewRecovered:  68 node count:  {0: 44, 1: 1519, 2: 437}
# Iteration:  5 NewSusceptible: -16 NewInfected:  -49 NewRecovered:  65 node count:  {0: 28, 1: 1470, 2: 502}
# ...

# %%
# %run
