# %%
# %matplotlib inline
# %run Visualization/choroplet_sample_view.py Recovered 15 5
# Out:
# Regione: Abruzzo, Recovered: 11, color: #dfffdf
# Regione: Basilicata, Recovered: 10, color: #e2ffe2
# Regione: Calabria, Recovered: 17, color: #cdffcd
# Regione: Campania, Recovered: 57, color: #58ff58
# Regione: Emilia-Romagna, Recovered: 51, color: #6aff6a
# Regione: Friuli-Venezia Giulia, Recovered: 11, color: #dfffdf
# Regione: Lazio, Recovered: 45, color: #7bff7b
# Regione: Liguria, Recovered: 17, color: #cdffcd
# Regione: Lombardia, Recovered: 87, color: #00ff00
# Regione: Marche, Recovered: 13, color: #d9ffd9
# Regione: Molise, Recovered: 1, color: #fcfffc
# Regione: Piemonte, Recovered: 29, color: #aaffaa
# Regione: Puglia, Recovered: 48, color: #72ff72
# Regione: Sardegna, Recovered: 17, color: #cdffcd
# Regione: Sicilia, Recovered: 54, color: #61ff61
# Regione: Toscana, Recovered: 51, color: #6aff6a
# Regione: Trentino-Alto Adige, Recovered: 5, color: #f0fff0
# Regione: Umbria, Recovered: 14, color: #d6ffd6
# Regione: Valle d'Aosta, Recovered: 0, color: #ffffff
# Regione: Veneto, Recovered: 64, color: #43ff43

# %%
# %matplotlib inline
# %run Visualization/choroplet_complete_view.py Recovered 15 5
# Out:
# Regione: Abruzzo, Recovered: 11, color: #dfffdf
# Regione: Basilicata, Recovered: 10, color: #e2ffe2
# Regione: Calabria, Recovered: 17, color: #cdffcd
# Regione: Campania, Recovered: 57, color: #58ff58
# Regione: Emilia-Romagna, Recovered: 51, color: #6aff6a
# Regione: Friuli-Venezia Giulia, Recovered: 11, color: #dfffdf
# Regione: Lazio, Recovered: 45, color: #7bff7b
# Regione: Liguria, Recovered: 17, color: #cdffcd
# Regione: Lombardia, Recovered: 87, color: #00ff00
# Regione: Marche, Recovered: 13, color: #d9ffd9
# Regione: Molise, Recovered: 1, color: #fcfffc
# Regione: Piemonte, Recovered: 29, color: #aaffaa
# Regione: Puglia, Recovered: 48, color: #72ff72
# Regione: Sardegna, Recovered: 17, color: #cdffcd
# Regione: Sicilia, Recovered: 54, color: #61ff61
# Regione: Toscana, Recovered: 51, color: #6aff6a
# Regione: Trentino-Alto Adige, Recovered: 5, color: #f0fff0
# Regione: Umbria, Recovered: 14, color: #d6ffd6
# Regione: Valle d'Aosta, Recovered: 0, color: #ffffff
# Regione: Veneto, Recovered: 64, color: #43ff43
