# %%
# %run main_choroplet.py
# Out:
# no display found. Using non-interactive Agg backend
# no display found. Using non-interactive Agg backend
#
#
# <---------TEST:  Debunking test 1: setting as initial recovered seed all the hub of the graph --------->
#
#
# INITIAL STATUS  {0: 1650, 1: 200, 2: 150}
# Iteration:  0 NewSusceptible: -329 NewInfected:  329 NewRecovered:  0 node count:  {0: 1321, 1: 529, 2: 150}
# Iteration:  1 NewSusceptible: -525 NewInfected:  455 NewRecovered:  70 node count:  {0: 796, 1: 984, 2: 220}
# Iteration:  2 NewSusceptible: -458 NewInfected:  381 NewRecovered:  77 node count:  {0: 338, 1: 1365, 2: 297}
# Iteration:  3 NewSusceptible: -217 NewInfected:  136 NewRecovered:  81 node count:  {0: 121, 1: 1501, 2: 378}
# Iteration:  4 NewSusceptible: -73 NewInfected:  -13 NewRecovered:  86 node count:  {0: 48, 1: 1488, 2: 464}
# Iteration:  5 NewSusceptible: -17 NewInfected:  -61 NewRecovered:  78 node count:  {0: 31, 1: 1427, 2: 542}
# ...

# %%
# %run Analysis/degree_distribution.py
