# %%
# %matplotlib inline
# %run Visualization/choroplet_sample_view.py Recovered 15 5
# Out:
# Regione: Abruzzo, Recovered: 16, color: #d4ffd4
# Regione: Basilicata, Recovered: 11, color: #e2ffe2
# Regione: Calabria, Recovered: 12, color: #dfffdf
# Regione: Campania, Recovered: 69, color: #48ff48
# Regione: Emilia-Romagna, Recovered: 55, color: #6dff6d
# Regione: Friuli-Venezia Giulia, Recovered: 14, color: #daffda
# Regione: Lazio, Recovered: 40, color: #95ff95
# Regione: Liguria, Recovered: 11, color: #e2ffe2
# Regione: Lombardia, Recovered: 96, color: #00ff00
# Regione: Marche, Recovered: 19, color: #cdffcd
# Regione: Molise, Recovered: 0, color: #ffffff
# Regione: Piemonte, Recovered: 33, color: #a7ffa7
# Regione: Puglia, Recovered: 52, color: #75ff75
# Regione: Sardegna, Recovered: 15, color: #d7ffd7
# Regione: Sicilia, Recovered: 60, color: #60ff60
# Regione: Toscana, Recovered: 43, color: #8dff8d
# Regione: Trentino-Alto Adige, Recovered: 2, color: #fafffa
# Regione: Umbria, Recovered: 15, color: #d7ffd7
# Regione: Valle d'Aosta, Recovered: 0, color: #ffffff
# ...

# %%
# %matplotlib inline
# %run Visualization/choroplet_complete_view.py Recovered 15 5
# Out:
# Regione: Abruzzo, Recovered: 16, color: #d4ffd4
# Regione: Basilicata, Recovered: 11, color: #e2ffe2
# Regione: Calabria, Recovered: 12, color: #dfffdf
# Regione: Campania, Recovered: 69, color: #48ff48
# Regione: Emilia-Romagna, Recovered: 55, color: #6dff6d
# Regione: Friuli-Venezia Giulia, Recovered: 14, color: #daffda
# Regione: Lazio, Recovered: 40, color: #95ff95
# Regione: Liguria, Recovered: 11, color: #e2ffe2
# Regione: Lombardia, Recovered: 96, color: #00ff00
# Regione: Marche, Recovered: 19, color: #cdffcd
# Regione: Molise, Recovered: 0, color: #ffffff
# Regione: Piemonte, Recovered: 33, color: #a7ffa7
# Regione: Puglia, Recovered: 52, color: #75ff75
# Regione: Sardegna, Recovered: 15, color: #d7ffd7
# Regione: Sicilia, Recovered: 60, color: #60ff60
# Regione: Toscana, Recovered: 43, color: #8dff8d
# Regione: Trentino-Alto Adige, Recovered: 2, color: #fafffa
# Regione: Umbria, Recovered: 15, color: #d7ffd7
# Regione: Valle d'Aosta, Recovered: 0, color: #ffffff
# ...
